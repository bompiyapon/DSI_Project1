# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*
#
# Problem statement:
#     I'm the representative of consultance agency in the USA which give and advice to the College Board (which is associate to run SAT test). How to increase the percent of SAT participant by state overall USA
#     I will provide the data to compare which test they would like to take in order to get in university from the previous year from 2017-2019 compare participant and average score to get some insight. Also provide recommendation for them.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Education Consultancy score range SAT / ACT
# ### if ur score in this range will pass or not
# ### what will be impact / interprete

# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import string
uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase
punc = string.punctuation
number = string.digits

# %% [markdown]
# <b>Import data</b>

# %%
sat_act_by_college_csv = 'data/sat_act_by_college.csv'
sat_act_by_college = pd.read_csv(sat_act_by_college_csv)
sat_2017_csv = 'data/sat_2017.csv'
sat_2017 = pd.read_csv(sat_2017_csv)
sat_2018_csv = 'data/sat_2018.csv'
sat_2018 = pd.read_csv(sat_2018_csv)
sat_2019_csv = 'data/sat_2019.csv'
sat_2019 = pd.read_csv(sat_2019_csv)
act_2017_csv = 'data/act_2017.csv'
act_2017 = pd.read_csv(act_2017_csv)
act_2018_csv = 'data/act_2018.csv'
act_2018 = pd.read_csv(act_2018_csv)
act_2019_csv = 'data/act_2019.csv'
act_2019 = pd.read_csv(act_2019_csv)

# %%
###which state should sat should increase participant
###which state should
#2017-2019 -> which state
#check if information for college which state have more college
print(act_2017.head())
print(act_2018.head())
print(act_2019.head())
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
print(sat_2017.head())
print(sat_2018.head())
print(sat_2019.head())
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
# ...

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# I insert outside research in the following analysis along this jupyter notebook sheet

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_mean(df,field):
    sum_data = 0
    number_data = len(df)
    for i in range(len(df)):
        sum_data += df.loc[i,field]
    mean = sum_data/number_data
    return(mean)

# %%
mean_sat2019_overall = calculate_mean(sat_2019,"Total")
mean_sat2019_ebrw = calculate_mean(sat_2019,"EBRW")
mean_sat2019_math = calculate_mean(sat_2019,"Math")
print(mean_sat2019_overall,mean_sat2019_ebrw,mean_sat2019_math)
# Out:
# 1106.5283018867924 558.0 548.4716981132076

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def compute_stdev(df,field):
         
    number = len(df)
    mean = calculate_mean(df,field)
    total = 0
    
    for x in df[field]:
        total += (x-mean)**2
        
    variance = total / number
    stdev = variance**(0.5)

    return stdev

# %%
compute_stdev(sat_2019,'Math')
# Out:
# 53.27522124781091

# %%
np.std(sat_2019['Math'],ddof=0)
# Out:
# 53.27522124781091

# %%
sat_2019['Math'].std()
# Out:
# 53.78504359362972

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def change_percentage(df,word):
    df[word] = df[word].str.rstrip('%').astype('float') / 100.0
    return df

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# ## Data Import and Cleaning

# %%
###Remove like in part 2 no.7 but do it here first to easier to use column name

def remove_punc(arr_str):
    temp_list=[]
    for column in arr_str.columns:
        temp_str = ''
        for char in column.lower():
            if ((char in uppercase) or (char in lowercase) or char == '_' or (char in number)):
                temp_str += char
            elif char == ' ':
                temp_str += '_'
        temp_list.append(temp_str)
    arr_str.columns = temp_list
    return arr_str

# %%
remove_punc(act_2017)
remove_punc(act_2018)
remove_punc(act_2019)
remove_punc(sat_2017)
remove_punc(sat_2018)
remove_punc(sat_2019)

sat_2019.rename(columns={'ebrw':'evidencebased_reading_and_writing'},inplace=True)

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# 1.Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
# Code:
sat_2017.head()
# Out:
#         state participation  evidencebased_reading_and_writing  math  total
# 0     Alabama            5%                                593   572   1165
# 1      Alaska           38%                                547   533   1080
# 2     Arizona           30%                                563   553   1116
# 3    Arkansas            3%                                614   594   1208
# 4  California           53%                                531   524   1055

# %%
act_2018.head()
# Out:
#         state participation  composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %% [markdown]
# 2. Check for missing values.

# %%
sat_2017.isnull().sum()
# Out:
# state                                0
# participation                        0
# evidencebased_reading_and_writing    0
# math                                 0
# total                                0
# dtype: int64

# %%
sat_2018.isnull().sum()
# Out:
# state                                0
# participation                        0
# evidencebased_reading_and_writing    0
# math                                 0
# total                                0
# dtype: int64

# %%
sat_2019.isnull().sum()
# Out:
# state                                0
# participation_rate                   0
# evidencebased_reading_and_writing    0
# math                                 0
# total                                0
# dtype: int64

# %%
act_2017.isnull().sum()
# Out:
# state            0
# participation    0
# english          0
# math             0
# reading          0
# science          0
# composite        0
# dtype: int64

# %%
act_2018.isnull().sum()
# Out:
# state            0
# participation    0
# composite        0
# dtype: int64

# %%
act_2019.isnull().sum()
# Out:
# state            0
# participation    0
# composite        0
# dtype: int64

# %% [markdown]
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
#sat_2019
sat_2019.describe()
# Out:
#        evidencebased_reading_and_writing        math        total
# count                          53.000000   53.000000    53.000000
# mean                          558.000000  548.471698  1106.528302
# std                            47.554422   53.785044   100.994784
# min                           483.000000  445.000000   935.000000
# 25%                           518.000000  506.000000  1024.000000
# 50%                           550.000000  545.000000  1097.000000
# 75%                           610.000000  596.000000  1200.000000
# max                           636.000000  648.000000  1284.000000

# %%
sat_2018.describe()
# Out:
#        evidencebased_reading_and_writing        math        total
# count                          51.000000   51.000000    51.000000
# mean                          563.686275  556.235294  1120.019608
# std                            47.502627   47.772623    94.155083
# min                           480.000000  480.000000   977.000000
# 25%                           534.500000  522.500000  1057.500000
# 50%                           552.000000  544.000000  1098.000000
# 75%                           610.500000  593.500000  1204.000000
# max                           643.000000  655.000000  1298.000000

# %%
sat_2019['participation_rate'].unique()
# Out:
# array(['7%', '41%', '31%', '6%', '63%', '100%', '94%', '71%', '54%',
#        '66%', '3%', '4%', '5%', '99%', '82%', '81%', '9%', '20%', '95%',
#        '18%', '79%', '51%', '2%', '19%', '22%', '70%', '—', '68%'],
#       dtype=object)

# %%
#act_2019.columns
act_2019['participation'].unique()
# Out:
# array(['100%', '38%', '73%', '23%', '27%', '22%', '13%', '32%', '54%',
#        '49%', '80%', '31%', '35%', '29%', '66%', '72%', '6%', '28%',
#        '21%', '19%', '95%', '82%', '14%', '25%', '63%', '96%', '42%',
#        '17%', '12%', '78%', '75%', '39%', '20%', '24%', '52%'],
#       dtype=object)

# %%
#dumplicate Maine
act_2018[act_2018['state']=='Maine']
#temp_act_2018 = act_2018
#temp_act_2018.drop_duplicates(subset = "state",inplace=True)
#temp_act_2018[temp_act_2018['state']=='Maine']
# Out:
#     state participation  composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %% [markdown]
# 4. Fix any errors you identified in steps 2-3.

# %%
sat_2019['participation_rate'] = sat_2019['participation_rate'].replace('—','0%')

# %%
act_2017['composite'] = act_2017['composite'].replace('20.2x','20.20')

# %%
act_2018.drop_duplicates(subset = "state",inplace=True)

# %% [markdown]
# 5. Display the data types of each feature.

# %%
print(sat_2019.dtypes)
print('////////////////////')
print(act_2019.dtypes)
print('////////////////////')
# Out:
# state                                object
# participation_rate                   object
# evidencebased_reading_and_writing     int64
# math                                  int64
# total                                 int64
# dtype: object
# ////////////////////
# state             object
# participation     object
# composite        float64
# dtype: object
# ////////////////////

# %% [markdown]
# 6. Fix any incorrect data types found in step 5.
#
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! Hint: use .map() or .apply().

# %%
act_2017.head()
# Out:
#       state participation  english  math  reading  science composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017['composite'] = act_2017['composite'].astype(float)

# %%
sat_2019.rename(columns={'participation_rate':'participation'},inplace=True)

# %%
sat_2019.head()
# Out:
#         state participation  evidencebased_reading_and_writing  math  total
# 0     Alabama            7%                                583   560   1143
# 1      Alaska           41%                                556   541   1097
# 2     Arizona           31%                                569   565   1134
# 3    Arkansas            6%                                582   559   1141
# 4  California           63%                                534   531   1065

# %%
change_percentage(act_2017,'participation')
change_percentage(act_2018,'participation')
change_percentage(act_2019,'participation')
change_percentage(sat_2017,'participation')
change_percentage(sat_2018,'participation')
change_percentage(sat_2019,'participation')
# Out:
#                    state  participation  evidencebased_reading_and_writing  \
# 0                Alabama           0.07                                583
# 1                 Alaska           0.41                                556
# 2                Arizona           0.31                                569
# 3               Arkansas           0.06                                582
# 4             California           0.63                                534
# 5               Colorado           1.00                                518
# 6            Connecticut           1.00                                529
# 7               Delaware           1.00                                499
# 8   District of Columbia           0.94                                495
# 9                Florida           1.00                                516
# 10               Georgia           0.71                                538
# ...

# %% [markdown]
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition to df['column_name']).
#     - Column names should be unique and informative.

# %%
def remove_punc(arr_str):
    temp_list=[]
    for column in arr_str.columns:
        temp_str = ''
        for char in column.lower():
            if ((char in uppercase) or (char in lowercase) or char == '_' or (char in number)):
                temp_str += char
            elif char == ' ':
                temp_str += '_'
        temp_list.append(temp_str)
    arr_str.columns = temp_list
    return arr_str

# %%
remove_punc(act_2017)
remove_punc(act_2018)
remove_punc(act_2019)
remove_punc(sat_2017)
remove_punc(sat_2018)
remove_punc(sat_2019)
#evidencebased_reading_and_writing
sat_2019.rename(columns={'ebrw':'evidencebased_reading_and_writing'},inplace=True)
print(sat_2019.columns)
print(act_2019.columns)
# Out:
# Index(['state', 'participation', 'evidencebased_reading_and_writing', 'math',
#        'total'],
#       dtype='object')
# Index(['state', 'participation', 'composite'], dtype='object')

# %% [markdown]
# 8. Drop unnecessary rows (if needed).

# %%
act_2017_drop = act_2017.drop(['english','math','reading','science'],axis=1)
act_2017_drop.head()
# Out:
#       state  participation  composite
# 0  National           0.60       21.0
# 1   Alabama           1.00       19.2
# 2    Alaska           0.65       19.8
# 3   Arizona           0.62       19.7
# 4  Arkansas           1.00       19.4

# %%
sat_2019.head()
# Out:
#         state  participation  evidencebased_reading_and_writing  math  total
# 0     Alabama           0.07                                583   560   1143
# 1      Alaska           0.41                                556   541   1097
# 2     Arizona           0.31                                569   565   1134
# 3    Arkansas           0.06                                582   559   1141
# 4  California           0.63                                534   531   1065

# %%
sat_2017_drop = sat_2017.drop(['evidencebased_reading_and_writing','math'],axis=1)
sat_2018_drop = sat_2018.drop(['evidencebased_reading_and_writing','math'],axis=1)
sat_2019_drop = sat_2019.drop(['evidencebased_reading_and_writing','math'],axis=1)

# %%
sat_2019_drop.head()
# Out:
#         state  participation  total
# 0     Alabama           0.07   1143
# 1      Alaska           0.41   1097
# 2     Arizona           0.31   1134
# 3    Arkansas           0.06   1141
# 4  California           0.63   1065

# %% [markdown]
# 9. Merge dataframes that can be merged.

# %%
merge_act_1 = pd.merge(act_2017_drop, act_2018, on = 'state',how='left')
merge_act_1.rename(columns={'participation_x':'participation_2017',
                            'composite_x':'composite_2017',
                            'participation_y':'participation_2018',
                            'composite_y':'composite_2018',},
                   inplace=True)
merge_act = pd.merge(merge_act_1,act_2019, on ='state',how='left')
merge_act.rename(columns={'participation':'participation_2019',
                            'composite':'composite_2019',
                           },
                   inplace=True)
merge_act.head()
# Out:
#       state  participation_2017  composite_2017  participation_2018  \
# 0  National                0.60            21.0                 NaN
# 1   Alabama                1.00            19.2                1.00
# 2    Alaska                0.65            19.8                0.33
# 3   Arizona                0.62            19.7                0.66
# 4  Arkansas                1.00            19.4                1.00
#
#    composite_2018  participation_2019  composite_2019
# 0             NaN                0.52            20.7
# 1            19.1                1.00            18.9
# 2            20.8                0.38            20.1
# 3            19.2                0.73            19.0
# 4            19.4                1.00            19.3

# %%
merge_sat_1 = pd.merge(sat_2017_drop, sat_2018_drop, on = 'state',how='left')
merge_sat_1.rename(columns={'participation_x':'participation_2017',
                            'total_x':'total_2017',
                            'participation_y':'participation_2018',
                            'total_y':'total_2018'},
                   inplace=True)
merge_sat = pd.merge(merge_sat_1, sat_2019_drop, on = 'state',how='left')
merge_sat.rename(columns={'participation':'participation_2019',
                            'total':'total_2019'},
                   inplace=True)
merge_sat.head()
# Out:
#         state  participation_2017  total_2017  participation_2018  total_2018  \
# 0     Alabama                0.05        1165                0.06        1166
# 1      Alaska                0.38        1080                0.43        1106
# 2     Arizona                0.30        1116                0.29        1149
# 3    Arkansas                0.03        1208                0.05        1169
# 4  California                0.53        1055                0.60        1076
#
#    participation_2019  total_2019
# 0                0.07        1143
# 1                0.41        1097
# 2                0.31        1134
# 3                0.06        1141
# 4                0.63        1065

# %%
sat_act_participation = pd.merge(merge_act,merge_sat,on='state',how='left',suffixes=("_act","_sat"))
sat_act_participation = sat_act_participation.drop(sat_act_participation.index[0])

# %%
merge_act.fillna(value=0,inplace = True)
merge_sat.fillna(value=0,inplace = True)

# %% [markdown]
# 10. Perform any additional cleaning that you feel is necessary.

# %% [markdown]
# 11. Save your cleaned and merged dataframes as csv files.

# %%
merge_sat.to_csv('export_data/act_2017_to_2019',index=False,header=True)
merge_act.to_csv('export_data/sat_2017_to_2019',index=False,header=True)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ## Data dict merge_act
# - Combine 3 year of participant and average score of act file together

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|act_2017.csv|Take name of state|
# |participation_2017|float64|act_2017.csv|Number of participant compare to whole state of 2017|
# |composite_2017|float64|act_2017.csv|Average score of ACT of that state in 2017|
# |participation_2018|float64|act_2018.csv|Number of participant compare to whole state of 2018|
# |composite_2018|float64|act_2018.csv|Average score of ACT of that state in 2017|
# |participation_2019|float64|act_2019.csv|Number of participant compare to whole state of 2019|
# |composite_2019|float64|act_2019.csv|Average score of ACT of that state in 2017|

# %% [markdown]
# ## Data dict merge_act
# - Combine 3 year of participant and average score of sat file together

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat_2017.csv|Take name of state|
# |participation_2017|float64|sat_2017.csv|Number of SAT participant compare to whole state of 2017|
# |total_2017|float64|sat_2017.csv|Average score of SAT of that state in 2017|
# |participation_2018|float64|sat_2018.csv|Number of SAT participant compare to whole state of 2018|
# |total_2018|float64|sat_2018.csv|Average score of SAT of that state in 2017|
# |participation_2019|float64|sat_2019.csv|Number of SAT participant compare to whole state of 2019|
# |total_2019|float64|sat_2019.csv|Average score of SAT of that state in 2017|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# 1. Summary Statistics

# %%
merge_act.describe()
# Out:
#        participation_2017  composite_2017  participation_2018  composite_2018  \
# count           52.000000       52.000000           52.000000       52.000000
# mean             0.651538       21.509615            0.599231       20.628846
# std              0.318325        2.002083            0.355610        4.651727
# min              0.080000       17.800000            0.000000        0.000000
# 25%              0.310000       19.800000            0.267500       19.550000
# 50%              0.680000       21.400000            0.655000       20.750000
# 75%              1.000000       23.600000            1.000000       23.550000
# max              1.000000       25.500000            1.000000       25.600000
#
#        participation_2019  composite_2019
# count           52.000000       52.000000
# mean             0.585385       21.450000
# std              0.341883        2.175487
# min              0.060000       17.900000
# 25%              0.247500       19.800000
# ...

# %%
merge_sat.describe()
# Out:
#        participation_2017   total_2017  participation_2018   total_2018  \
# count           51.000000    51.000000           51.000000    51.000000
# mean             0.398039  1126.098039            0.457451  1120.019608
# std              0.352766    92.494812            0.373143    94.155083
# min              0.020000   950.000000            0.020000   977.000000
# 25%              0.040000  1055.500000            0.045000  1057.500000
# 50%              0.380000  1107.000000            0.520000  1098.000000
# 75%              0.660000  1212.000000            0.775000  1204.000000
# max              1.000000  1295.000000            1.000000  1298.000000
#
#        participation_2019   total_2019
# count           51.000000    51.000000
# mean             0.490588  1113.078431
# std              0.387476    97.197910
# min              0.020000   943.000000
# 25%              0.055000  1038.000000
# 50%              0.540000  1097.000000
# 75%              0.820000  1210.000000
# ...

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
merge_act['participation_2018'].unique()
# Out:
# array([0.  , 1.  , 0.33, 0.66, 0.27, 0.3 , 0.26, 0.17, 0.53, 0.89, 0.36,
#        0.43, 0.32, 0.68, 0.71, 0.07, 0.31, 0.25, 0.22, 0.99, 0.16, 0.67,
#        0.98, 0.42, 0.2 , 0.15, 0.77, 0.45, 0.24, 0.65])

# %%
sd = {column:compute_stdev(merge_act,column) for column in merge_act if column != 'state'}
sd
# Out:
# {'participation_2017': 0.3152495020150073,
#  'composite_2017': 1.9827389384951444,
#  'participation_2018': 0.3521737232687111,
#  'composite_2018': 4.606781645593539,
#  'participation_2019': 0.33857996180008104,
#  'composite_2019': 2.154467630119044}

# %% [markdown]
# 3. Investigate trends in the data.
#
#    - Using sorting and/or masking (along with the .head() method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on both tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     You should comment on your findings at each step in a markdown cell below your code block. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# 1. Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?

# %%
min_participant_2017 = merge_act['participation_2017'].min()
min_participant_2018 = merge_act['participation_2018'].min()
min_participant_2019 = merge_act['participation_2019'].min()
max_participant_2017 = merge_act['participation_2017'].max()
max_participant_2018 = merge_act['participation_2018'].max()
max_participant_2019 = merge_act['participation_2019'].max()

min_act_2017 = merge_act[merge_act['participation_2017']==min_participant_2017]['state']
min_act_2018 = merge_act[merge_act['participation_2018']==min_participant_2018]['state']
min_act_2019 = merge_act[merge_act['participation_2019']==min_participant_2019]['state']
max_act_2017 = merge_act[merge_act['participation_2017']==max_participant_2017]['state']
max_act_2018 = merge_act[merge_act['participation_2018']==max_participant_2018]['state']
max_act_2019 = merge_act[merge_act['participation_2019']==max_participant_2019]['state']

# %%
max_participant_2017
# Out:
# 1.0

# %%
###MAX act participant
print("Most participant act 2017 is ",max_act_2017.values.tolist(),",which has"
      ,max_participant_2017*100,"percent participant")
print("Most participant act 2018 is ",max_act_2018.values.tolist(),",which has"
      ,max_participant_2018*100,"percent participant")
print("Most participant act 2019 is ",max_act_2019.values.tolist(),",which has"
      ,max_participant_2019*100,"percent participant")
# Out:
# Most participant act 2017 is  ['Alabama', 'Arkansas', 'Colorado', 'Kentucky', 'Louisiana', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nevada', 'North Carolina', 'Oklahoma', 'South Carolina', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming'] ,which has 100.0 percent participant
# Most participant act 2018 is  ['Alabama', 'Arkansas', 'Kentucky', 'Louisiana', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'North Carolina', 'Ohio', 'Oklahoma', 'South Carolina', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming'] ,which has 100.0 percent participant
# Most participant act 2019 is  ['Alabama', 'Arkansas', 'Kentucky', 'Louisiana', 'Mississippi', 'Montana', 'Nebraska', 'Nevada', 'North Carolina', 'Ohio', 'Oklahoma', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming'] ,which has 100.0 percent participant

# %%
###MIN act participant
print("Least participant act 2017 is ",min_act_2017.values.tolist(),",which has"
      ,min_participant_2017*100,"percent participant")
print("Least participant act 2018 is ",min_act_2018.values.tolist(),",which has"
      ,min_participant_2018*100,"percent participant")
print("Least participant act 2019 is ",min_act_2019.values.tolist(),",which has"
      ,min_participant_2019*100,"percent participant")
# Out:
# Least participant act 2017 is  ['Maine'] ,which has 8.0 percent participant
# Least participant act 2018 is  ['National', 'District of Columbia'] ,which has 0.0 percent participant
# Least participant act 2019 is  ['Maine'] ,which has 6.0 percent participant

# %%
min_participant_2017_sat = merge_sat['participation_2017'].min()
min_participant_2018_sat = merge_sat['participation_2018'].min()
min_participant_2019_sat = merge_sat['participation_2019'].min()
max_participant_2017_sat = merge_sat['participation_2017'].max()
max_participant_2018_sat = merge_sat['participation_2018'].max()
max_participant_2019_sat = merge_sat['participation_2019'].max()

min_sat_2017 = merge_sat[merge_sat['participation_2017']==min_participant_2017_sat]['state']
min_sat_2018 = merge_sat[merge_sat['participation_2018']==min_participant_2018_sat]['state']
min_sat_2019 = merge_sat[merge_sat['participation_2019']==min_participant_2019_sat]['state']
max_sat_2017 = merge_sat[merge_sat['participation_2017']==max_participant_2017_sat]['state']
max_sat_2018 = merge_sat[merge_sat['participation_2018']==max_participant_2018_sat]['state']
max_sat_2019 = merge_sat[merge_sat['participation_2019']==max_participant_2019_sat]['state']

# %%
print("Most participant sat 2017 is ",min_sat_2017.values.tolist(),",which has"
      ,min_participant_2017_sat*100,"percent participant")
print("Most participant sat 2018 is ",min_sat_2018.values.tolist(),",which has"
      ,min_participant_2018_sat*100,"percent participant")
print("Most participant sat 2019 is ",min_sat_2019.values.tolist(),",which has"
      ,min_participant_2019_sat*100,"percent participant")
# Out:
# Most participant sat 2017 is  ['Iowa', 'Mississippi', 'North Dakota'] ,which has 2.0 percent participant
# Most participant sat 2018 is  ['North Dakota'] ,which has 2.0 percent participant
# Most participant sat 2019 is  ['North Dakota'] ,which has 2.0 percent participant

# %%
print("Most participant sat 2017 is ",max_sat_2017.values.tolist(),",which has"
      ,max_participant_2017_sat*100,"percent participant")
print("Most participant sat 2018 is ",max_sat_2018.values.tolist(),",which has"
      ,max_participant_2018_sat*100,"percent participant")
print("Most participant sat 2019 is ",max_sat_2019.values.tolist(),",which has"
      ,max_participant_2019_sat*100,"percent participant")
# Out:
# Most participant sat 2017 is  ['Connecticut', 'Delaware', 'District of Columbia', 'Michigan'] ,which has 100.0 percent participant
# Most participant sat 2018 is  ['Colorado', 'Connecticut', 'Delaware', 'Idaho', 'Michigan'] ,which has 100.0 percent participant
# Most participant sat 2019 is  ['Colorado', 'Connecticut', 'Delaware', 'Florida', 'Idaho', 'Illinois', 'Michigan', 'Rhode Island'] ,which has 100.0 percent participant

# %% [markdown]
# 2. Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?

# %%
#all_mean = {column:calculate_mean(merge_act,column) for column in merge_act if column != 'state'}
#all_mean
#all_mean.pop()

# %%
buttom_composite_2017 = merge_act.sort_values('composite_2017')[['state','composite_2017']].head(1)
buttom_composite_2018 = merge_act.sort_values('composite_2018')[['state','composite_2018']].head(1)
buttom_composite_2019 = merge_act.sort_values('composite_2019')[['state','composite_2019']].head(1)

top_composite_2017 = merge_act.sort_values('composite_2017')[['state','composite_2017']].tail(1)
top_composite_2018 = merge_act.sort_values('composite_2018')[['state','composite_2018']].tail(1)
top_composite_2019 = merge_act.sort_values('composite_2019')[['state','composite_2019']].tail(1)

print("Lowest ACT average score 2017 is",buttom_composite_2017.values.tolist(),
      "\n2018 is",buttom_composite_2018.values.tolist(),"\n2019 is",buttom_composite_2019.values.tolist())
print("Top ACT average score 2017 is",top_composite_2017.values.tolist(),
      "\n2018 is",top_composite_2018.values.tolist(),"\n2019 is",top_composite_2019.values.tolist())
# Out:
# Lowest ACT average score 2017 is [['Nevada', 17.8]]
# 2018 is [['National', 0.0]]
# 2019 is [['Nevada', 17.9]]
# Top ACT average score 2017 is [['New Hampshire', 25.5]]
# 2018 is [['Connecticut', 25.6]]
# 2019 is [['Massachusetts', 25.5]]

# %%
buttom_total_2017 = merge_sat.sort_values('total_2017')[['state','total_2017']].head(1)
buttom_total_2018 = merge_sat.sort_values('total_2018')[['state','total_2018']].head(1)
buttom_total_2019 = merge_sat.sort_values('total_2019')[['state','total_2019']].head(1)

top_total_2017 = merge_sat.sort_values('total_2017')[['state','total_2017']].tail(1)
top_total_2018 = merge_sat.sort_values('total_2018')[['state','total_2018']].tail(1)
top_total_2019 = merge_sat.sort_values('total_2019')[['state','total_2019']].tail(1)

print("Lowest ACT average score 2017 is",buttom_total_2017.values.tolist(),
      "\n2018 is",buttom_total_2018.values.tolist(),"\n2019 is",buttom_total_2019.values.tolist())
print("Top ACT average score 2017 is",top_total_2017.values.tolist(),
      "\n2018 is",top_total_2018.values.tolist(),"\n2019 is",top_total_2019.values.tolist())
# Out:
# Lowest ACT average score 2017 is [['District of Columbia', 950]]
# 2018 is [['District of Columbia', 977]]
# 2019 is [['West Virginia', 943]]
# Top ACT average score 2017 is [['Minnesota', 1295]]
# 2018 is [['Minnesota', 1298]]
# 2019 is [['Minnesota', 1284]]

# %% [markdown]
# 3. Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
def participation_change(previous_year,following_year):
    not_change_participant = []
    for state in following_year:
        if state in previous_year:
            not_change_participant.append(state)
    return not_change_participant

# %%
act_2017_100 = merge_act[merge_act['participation_2017']==1]['state'].values.tolist()
act_2018_100 = merge_act[merge_act['participation_2018']==1]['state'].values.tolist()
act_2018_100 = merge_act[merge_act['participation_2019']==1]['state'].values.tolist()

sat_2017_100 = merge_sat[merge_sat['participation_2017']==1]['state'].values.tolist()
sat_2018_100 = merge_sat[merge_sat['participation_2018']==1]['state'].values.tolist()
sat_2018_100 = merge_sat[merge_sat['participation_2019']==1]['state'].values.tolist()

# %%
participation_change(act_2017_100,act_2018_100)
# Out:
# ['Alabama',
#  'Arkansas',
#  'Kentucky',
#  'Louisiana',
#  'Mississippi',
#  'Montana',
#  'Nevada',
#  'North Carolina',
#  'Oklahoma',
#  'Tennessee',
#  'Utah',
#  'Wisconsin',
#  'Wyoming']

# %% [markdown]
# <b>State which number of ACT participant change during 2017-2018 is ['Alabama','Arkansas', 'Kentucky', 'Louisiana', 'Mississippi', 'Montana', 'Nevada', 'North Carolina', 'Oklahoma', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming']</b><br>
# <b>*** For furthermore change parameter to call function to see***</b>

# %% [markdown]
# 4. Do any states show have >50% participation on both tests each year?

# %%
def compare_state(state1,state2):
    match_state = []
    for state in state1:
        if state in state2:
            match_state.append(state)
    return match_state

# %%
act_50_2017 = merge_act[merge_act['participation_2017']>=0.5]['state'].values.tolist()
sat_50_2017 = merge_sat[merge_sat['participation_2017']>=0.5]['state'].values.tolist()
act_50_2018 = merge_act[merge_act['participation_2018']>=0.5]['state'].values.tolist()
sat_50_2018 = merge_sat[merge_sat['participation_2018']>=0.5]['state'].values.tolist()
act_50_2019 = merge_act[merge_act['participation_2019']>=0.5]['state'].values.tolist()
sat_50_2019 = merge_sat[merge_sat['participation_2019']>=0.5]['state'].values.tolist()
state_both_50_2017 = compare_state(act_50_2017,sat_50_2017)
state_both_50_2018 = compare_state(act_50_2018,sat_50_2018)
state_both_50_2019 = compare_state(act_50_2019,sat_50_2019)
print('State have both test participant > 50% in 2017',state_both_50_2017)
print('State have both test participant > 50% in 2018',state_both_50_2018)
print('State have both test participant > 50% in 2019',state_both_50_2019)
# Out:
# State have both test participant > 50% in 2017 ['Florida', 'Georgia', 'Hawaii', 'South Carolina']
# State have both test participant > 50% in 2018 ['Florida', 'Georgia', 'Hawaii', 'North Carolina', 'South Carolina']
# State have both test participant > 50% in 2019 ['Florida', 'Hawaii', 'North Carolina', 'South Carolina']

# %% [markdown]
# 6. Which colleges have the highest median SAT and ACT scores for admittance?

# %%
###Sat act by college

# %% [markdown]
# 7. Which California school districts have the highest and lowest mean test scores [ACT]

# %%
### CA file

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# <b>1. Use Seaborn's heatmap with pandas .corr() to visualize correlations between all numeric features.</b>

# %%
corr = sat_act_participation.corr()

# %%
#map relation of each column in dataframe

# Code
fig, ax = plt.subplots(figsize=(18, 8))

mask = np.zeros_like(corr) ###creating matrix of 0
mask[np.triu_indices_from(mask)] = True ### triu = triangle upper and make it one

sns.heatmap(corr,mask=mask,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(sat_act_participation)

# %%
sat_act_participation['participation_2017_act'].unique()
# Out:
# array([1.  , 0.65, 0.62, 0.31, 0.18, 0.32, 0.73, 0.55, 0.9 , 0.38, 0.93,
#        0.35, 0.67, 0.08, 0.28, 0.29, 0.84, 0.34, 0.66, 0.98, 0.75, 0.4 ,
#        0.23, 0.21, 0.8 , 0.45, 0.69])

# %% [markdown]
# <b>2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots</b>

# %%
###Plot distribution of participant by no. of state
###bar plot 
###sat 100/ act 0 why is it

plt.figure(figsize = (16,9))
f, axs = plt.subplots(2,2,figsize=(15,15))

ax1 = plt.subplot(3,2,1)
ax1.hist(sat_act_participation['participation_2017_act'],color='firebrick');
ax1.set_title('No. ACT school by percent participant 2017')
plt.xlabel('Percent participant')
plt.ylabel('No. of state')

ax2 = plt.subplot(3,2,2)
ax2.hist(sat_act_participation['participation_2017_sat'],color='darkblue');
ax2.set_title('No. SAT school by percent participant 2017')
plt.xlabel('Percent participant')
plt.ylabel('No. of state')

ax3 = plt.subplot(3,2,3)
ax3.hist(sat_act_participation['participation_2018_act'],color='firebrick');
ax3.set_title('No. ACT school by percent participant 2018')
plt.xlabel('Percent participant')
plt.ylabel('No. of state')

ax4 = plt.subplot(3,2,4)
ax4.hist(sat_act_participation['participation_2018_sat'],color='darkblue');
ax4.set_title('No. SAT school by percent participant 2018')
plt.xlabel('Percent participant')
plt.ylabel('No. of state')

ax5 = plt.subplot(3,2,5)
ax5.hist(sat_act_participation['participation_2019_act'],color='firebrick');
ax5.set_title('No. ACT school by percent participant 2019')
plt.xlabel('Percent participant')
plt.ylabel('No. of state')

ax6 = plt.subplot(3,2,6)
ax6.hist(sat_act_participation['participation_2019_sat'],color='darkblue');
ax6.set_title('No. SAT school by percent participant 2019')
plt.xlabel('Percent participant')
plt.ylabel('No. of state')
# Out:
# Text(0, 0.5, 'No. of state')

# %% [markdown]
# <b>3. Plot and interpret boxplots. </b>

# %%
sat_2019.head()
sat_act_participation.head()
#plt.boxplot(sat_2019['math']);
# Out:
#         state  participation_2017_act  composite_2017  participation_2018_act  \
# 1     Alabama                    1.00            19.2                    1.00
# 2      Alaska                    0.65            19.8                    0.33
# 3     Arizona                    0.62            19.7                    0.66
# 4    Arkansas                    1.00            19.4                    1.00
# 5  California                    0.31            22.8                    0.27
#
#    composite_2018  participation_2019_act  composite_2019  \
# 1            19.1                    1.00            18.9
# 2            20.8                    0.38            20.1
# 3            19.2                    0.73            19.0
# 4            19.4                    1.00            19.3
# 5            22.7                    0.23            22.6
#
#    participation_2017_sat  total_2017  participation_2018_sat  total_2018  \
# ...

# %%
#Participation rate SAT is quite lower than ACT past 3 year as you can see from boxplot 

plt.figure(figsize = (12,8))
f, axs = plt.subplots(2,2,figsize=(10,14))

plt.subplot(3,1,1)
ax1 = sat_act_participation.boxplot(column=['participation_2017_act','participation_2017_sat'],grid=False)
ax1.set_ylabel("Participation Rate")
ax1.set_title("Range participation rate 2017")

plt.subplot(3,1,2)
ax2 = sat_act_participation.boxplot(column=['participation_2018_act','participation_2018_sat'],grid=False)
ax2.set_ylabel("Participation Rate")
ax2.set_title("Range participation rate 2018")

plt.subplot(3,1,3)
ax3 = sat_act_participation.boxplot(column=['participation_2019_act','participation_2019_sat'],grid=False)
ax3.set_ylabel("Participation Rate")
ax3.set_title("Range participation rate 2019")
# Out:
# Text(0.5, 1.0, 'Range participation rate 2019')

# %%
sat_act_participation.head()
# Out:
#         state  participation_2017_act  composite_2017  participation_2018_act  \
# 1     Alabama                    1.00            19.2                    1.00
# 2      Alaska                    0.65            19.8                    0.33
# 3     Arizona                    0.62            19.7                    0.66
# 4    Arkansas                    1.00            19.4                    1.00
# 5  California                    0.31            22.8                    0.27
#
#    composite_2018  participation_2019_act  composite_2019  \
# 1            19.1                    1.00            18.9
# 2            20.8                    0.38            20.1
# 3            19.2                    0.73            19.0
# 4            19.4                    1.00            19.3
# 5            22.7                    0.23            22.6
#
#    participation_2017_sat  total_2017  participation_2018_sat  total_2018  \
# ...

# %%
##There is quite no different in this

plt.figure(figsize = (12,8))
f, axs = plt.subplots(2,2,figsize=(10,14))

plt.subplot(2,1,1)
ax1 = sat_act_participation.boxplot(column=['composite_2017','composite_2018','composite_2019'],grid=False)
ax1.set_ylabel("Composite score")
ax1.set_title("(ACT score) Range of score compare 2017-2019")

plt.subplot(2,1,2)
ax2 = sat_act_participation.boxplot(column=['total_2017','total_2018','total_2019'],grid=False)
ax2.set_ylabel("Total score")
ax2.set_title("(SAT score) Range of score compare 2017-2019")
# Out:
# Text(0.5, 1.0, '(SAT score) Range of score compare 2017-2019')

# %% [markdown]
# <b>4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space. </b>

# %%
###Compare participant sat-act by each year which is negative co-relation quite clearly seen

plt.figure(figsize=(10,10))
f, axs = plt.subplots(2,2,figsize=(10,16))

plt.subplot(3,1,1)
ax1 = sns.regplot(sat_act_participation['participation_2017_act'],sat_act_participation['participation_2017_sat'])
ax1.set_title("ACT V.S. SAT Participation rate 2017")

plt.subplot(3,1,2)
ax2 = sns.regplot(sat_act_participation['participation_2018_act'],sat_act_participation['participation_2018_sat'])
ax2.set_title("ACT V.S. SAT Participation rate 2018")

plt.subplot(3,1,3)
ax3 = sns.regplot(sat_act_participation['participation_2019_act'],sat_act_participation['participation_2019_sat'])
ax3.set_title("ACT V.S. SAT Participation rate 2019")
# Out:
# Text(0.5, 1.0, 'ACT V.S. SAT Participation rate 2019')

# %%
###It's seem to be trend

plt.figure(figsize=(10,10))
f, axs = plt.subplots(2,3,figsize=(10,16))

plt.subplot(3,2,1)
ax1 = sns.regplot(sat_act_participation['participation_2017_act'],sat_act_participation['composite_2017'])
ax1.set_title("ACT Participation rate and Averagre Score 2017")

plt.subplot(3,2,2)
ax2 = sns.regplot(sat_act_participation['participation_2017_sat'],sat_act_participation['total_2017'])
ax2.set_title("SAT Participation rate and Averagre Score 2017")

plt.subplot(3,2,3)
ax3 = sns.regplot(sat_act_participation['participation_2018_act'],sat_act_participation['composite_2018'])
ax3.set_title("ACT Participation rate and Averagre Score 2018")

plt.subplot(3,2,4)
ax4 = sns.regplot(sat_act_participation['participation_2018_sat'],sat_act_participation['total_2018'])
ax4.set_title("SAT Participation rate and Averagre Score 2018")

plt.subplot(3,2,5)
ax5 = sns.regplot(sat_act_participation['participation_2019_act'],sat_act_participation['composite_2019'])
ax5.set_title("ACT Participation rate and Averagre Score 2019")

plt.subplot(3,2,6)
ax6 = sns.regplot(sat_act_participation['participation_2019_sat'],sat_act_participation['total_2019'])
ax6.set_title("SAT Participation rate and Averagre Score 2019")
# Out:
# Text(0.5, 1.0, 'SAT Participation rate and Averagre Score 2019')

# %% [markdown]
# <b>5. Additional plots of your choosing. </b>

# %%
sat_2017_low = sat_act_participation[sat_act_participation['participation_2017_sat']<0.2]['state'].values.tolist()
sat_2018_low = sat_act_participation[sat_act_participation['participation_2018_sat']<0.2]['state'].values.tolist()
sat_2019_low = sat_act_participation[sat_act_participation['participation_2019_sat']<0.2]['state'].values.tolist()
print(sat_2017_low,sat_2018_low,sat_2019_low)
# Out:
# ['Alabama', 'Arkansas', 'Colorado', 'Illinois', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'New Mexico', 'North Dakota', 'Ohio', 'Oklahoma', 'South Dakota', 'Tennessee', 'Utah', 'West Virginia', 'Wisconsin', 'Wyoming'] ['Alabama', 'Arkansas', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'New Mexico', 'North Dakota', 'Ohio', 'Oklahoma', 'South Dakota', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming'] ['Alabama', 'Arkansas', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'New Mexico', 'North Dakota', 'Ohio', 'South Dakota', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming']

# %%
sat_2017_high = sat_act_participation[sat_act_participation['participation_2017_sat']>0.8]['state'].values.tolist()
sat_2018_high = sat_act_participation[sat_act_participation['participation_2018_sat']>0.8]['state'].values.tolist()
sat_2019_high = sat_act_participation[sat_act_participation['participation_2019_sat']>0.8]['state'].values.tolist()
print(sat_2017_high,sat_2018_high,sat_2019_high)
# Out:
# ['Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Idaho', 'Maine', 'Michigan', 'New Hampshire'] ['Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 'New Jersey', 'Rhode Island'] ['Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Idaho', 'Illinois', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'New Hampshire', 'New Jersey', 'Rhode Island', 'West Virginia']

# %%
temp_compare = compare_state(sat_2017_low,sat_2018_low)
least_three_year = compare_state(temp_compare,sat_2019_low)
#least_three_year

# %%
temp_compare2 = compare_state(sat_2017_high,sat_2018_high)
top_three_year = compare_state(temp_compare2,sat_2019_high)
top_three_year
# Out:
# ['Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Idaho',
#  'Maine',
#  'Michigan',
#  'New Hampshire']

# %%
##Create duplicate dataframe which filter sat participant below 20%

below_20_sat = sat_act_participation
for ind in sat_act_participation.index:
    if sat_act_participation['state'][ind] not in least_three_year:
        below_20_sat = below_20_sat.drop(ind)
below_20_sat[['participation_2017_sat','participation_2018_sat','participation_2019_sat']].head()
#below_20_sat[['participation_2017_sat','participation_2017_act']]
#below_20_sat[['participation_2018_sat','participation_2018_act']]
#below_20_sat[['participation_2019_sat','participation_2019_act']]
below_20_sat['state']
# Out:
# 1          Alabama
# 4         Arkansas
# 16            Iowa
# 17          Kansas
# 18        Kentucky
# 19       Louisiana
# 24       Minnesota
# 25     Mississippi
# 26        Missouri
# 27         Montana
# 28        Nebraska
# 32      New Mexico
# 35    North Dakota
# 36            Ohio
# 42    South Dakota
# 43       Tennessee
# 45            Utah
# 50       Wisconsin
# 51         Wyoming
# Name: state, dtype: object

# %%
##Create duplicate dataframe which filter sat participant above 80%

top_80_sat = sat_act_participation
for ind in sat_act_participation.index:
    if sat_act_participation['state'][ind] not in top_three_year:
        top_80_sat = top_80_sat.drop(ind)
top_80_sat
# Out:
#                    state  participation_2017_act  composite_2017  \
# 7            Connecticut                    0.31            25.2
# 8               Delaware                    0.18            24.1
# 9   District of Columbia                    0.32            24.2
# 13                 Idaho                    0.38            22.3
# 20                 Maine                    0.08            24.3
# 23              Michigan                    0.29            24.1
# 30         New Hampshire                    0.18            25.5
#
#     participation_2018_act  composite_2018  participation_2019_act  \
# 7                     0.26            25.6                    0.22
# 8                     0.17            23.8                    0.13
# 9                      NaN             NaN                    0.32
# 13                    0.36            22.3                    0.31
# 20                    0.07            24.0                    0.06
# ...

# %%
##Quite narrow that people are going state that have sat participant low act participat is high

sns.regplot(top_80_sat['participation_2017_act'],top_80_sat['participation_2017_sat'])
sns.regplot(top_80_sat['participation_2018_act'],top_80_sat['participation_2018_sat'])
sns.regplot(top_80_sat['participation_2019_act'],top_80_sat['participation_2019_sat'])

plt.ylim(0,1)
plt.xlim(0,1)
plt.title("Compare state SAT participation > 80% with ACT paticipation")
# Out:
# Text(0.5, 1.0, 'Compare state SAT participation > 80% with ACT paticipation')

# %%
sns.regplot(below_20_sat['participation_2017_act'],below_20_sat['participation_2017_sat'])
sns.regplot(below_20_sat['participation_2018_act'],below_20_sat['participation_2018_sat'])
sns.regplot(below_20_sat['participation_2019_act'],below_20_sat['participation_2019_sat'])
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
###How about the state that move out below 0.2
def compare_diff_state(state1,state2):
    diff_state = []
    for state in state1:
        if state not in state2:
            diff_state.append(state)
    return diff_state

# %%
###2017 - 2018 state that go above 20% participant is ['Colorado', 'Illinois', 'West Virginia']
###and not back in 2019

#look which state is go above 20% after 2018 compare with 2017
temp_compare = compare_diff_state(sat_2017_low,sat_2018_low)
#Check the state that go above 20% in 2018 any back lower in 2019
any_back = compare_state(temp_compare,sat_2019_low)
print(any_back)
# Out:
# []

# %%
#Quite interesting which it is grow highly and act drop significantly
sat_growing = sat_act_participation[(sat_act_participation['state']=='Colorado')|
                      (sat_act_participation['state']=='Illinois')|
                      (sat_act_participation['state']=='West Virginia')][['state',                                                                         
                                                                          'participation_2019_sat',
                                                                          'participation_2019_act',
                                                                          'participation_2018_sat',
                                                                          'participation_2018_act',
                                                                          'participation_2017_sat',
                                                                          'participation_2017_act',]]
sat_growing
# Out:
#             state  participation_2019_sat  participation_2019_act  \
# 6        Colorado                    1.00                    0.27
# 14       Illinois                    1.00                    0.35
# 49  West Virginia                    0.99                    0.49
#
#     participation_2018_sat  participation_2018_act  participation_2017_sat  \
# 6                     1.00                    0.30                    0.11
# 14                    0.99                    0.43                    0.09
# 49                    0.28                    0.65                    0.14
#
#     participation_2017_act
# 6                     1.00
# 14                    0.93
# 49                    0.69

# %%
## As you can see from the graph 3 state are incredibly growth to 100% and 

set_index = sat_growing.set_index("state")
test = set_index.transpose()
ax1 = test.plot(kind='barh')
ax1.set_xlabel('Participants Rate')
ax1.set_title("Compare growth participant rate in 3 State")
# Out:
# Text(0.5, 1.0, 'Compare growth participant rate in 3 State')

# %%
sat_growing_score = sat_act_participation[(sat_act_participation['state']=='Colorado')|
                      (sat_act_participation['state']=='Illinois')|
                      (sat_act_participation['state']=='West Virginia')][['state',
                                                                         'total_2017',
                                                                         'total_2018',
                                                                         'total_2019']]
sat_growing_score.set_index('state',inplace=True)
sat_growing_score
# Out:
#                total_2017  total_2018  total_2019
# state
# Colorado           1201.0      1025.0      1024.0
# Illinois           1115.0      1019.0      1013.0
# West Virginia      1086.0       999.0       943.0

# %%
###Slightly different although participant increasing significantly
###Therefore,it's not that  much coefficient relate between participant and

# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = sat_growing_score['total_2017']
bars2 = sat_growing_score['total_2018']
bars3 = sat_growing_score['total_2019']

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, bars1, color='darkorange', width=barWidth, edgecolor='white', label='Sat 2017')
plt.bar(r2, bars2, color='darkslateblue', width=barWidth, edgecolor='white', label='Sat 2018')
plt.bar(r3, bars3, color='darkslategrey', width=barWidth, edgecolor='white', label='Sat 2019')

# Add xticks on the middle of the group bars
plt.xlabel('State', fontweight='bold')
plt.ylabel('SAT score')
plt.xticks([r + barWidth for r in range(len(bars1))], ['Colorado', 'Illinois', 'West Virginia'])

plt.legend()
plt.title('3 State change in SAT score')
plt.show()

# %%
sat_2017_high = sat_act_participation[sat_act_participation['participation_2017_sat']>0.8]['state'].values.tolist()
sat_2018_high = sat_act_participation[sat_act_participation['participation_2018_sat']>0.8]['state'].values.tolist()
sat_2019_high = sat_act_participation[sat_act_participation['participation_2019_sat']>0.8]['state'].values.tolist()

# %%
#sat_2019_high

# %%
###Which is great is high still high participant
temp_compare = compare_state(sat_2017_high,sat_2018_high)
least_three_year = compare_state(temp_compare,sat_2019_high)
print(temp_compare)
print(least_three_year)
compare_diff_state(temp_compare,least_three_year)
# Out:
# ['Connecticut', 'Delaware', 'District of Columbia', 'Idaho', 'Maine', 'Michigan', 'New Hampshire']
# ['Connecticut', 'Delaware', 'District of Columbia', 'Idaho', 'Maine', 'Michigan', 'New Hampshire']
# []

# %%
### Then back to score
### ACT lowest is Nevada 3 years in a row
### While Top 3 quite have no different Top state like Massachusetts and Connecticut famous in education 
print("Lowest ACT average score 2017 is",buttom_composite_2017.values.tolist(),
      "\n2018 is",buttom_composite_2018.values.tolist(),"\n2019 is",buttom_composite_2019.values.tolist())
print("Top ACT average score 2017 is",top_composite_2017.values.tolist(),
      "\n2018 is",top_composite_2018.values.tolist(),"\n2019 is",top_composite_2019.values.tolist())
top1_act = sat_act_participation.sort_values('composite_2017',ascending=False)[['state','composite_2017']].head(3)
top2_act = sat_act_participation.sort_values('composite_2018',ascending=False)[['state','composite_2018']].head(3)
top3_act = sat_act_participation.sort_values('composite_2019',ascending=False)[['state','composite_2019']].head(3)

plt.figure(figsize=(12,8))

ax1 = plt.subplot(3,1,1)
ax1.bar(top1_act['state'],top1_act['composite_2017'])

ax2 = plt.subplot(3,1,2)
ax2.bar(top2_act['state'],top2_act['composite_2018'])

ax3 = plt.subplot(3,1,3)
ax3.bar(top3_act['state'],top3_act['composite_2019'])

#top1_act.plot(kind='bar')
#ax.bar(top1_act,height=30)
#sat_act_participation.head()
# Out:
# Lowest ACT average score 2017 is [['Nevada', 17.8]]
# 2018 is [['National', 0.0]]
# 2019 is [['Nevada', 17.9]]
# Top ACT average score 2017 is [['New Hampshire', 25.5]]
# 2018 is [['Connecticut', 25.6]]
# 2019 is [['Massachusetts', 25.5]]
# <BarContainer object of 3 artists>

# %%
#SAT top state was  Minnesota 
# therefore, if you are focus on getting scholarship recommend to test in this

print("Lowest ACT average score 2017 is",buttom_total_2017.values.tolist(),
      "\n2018 is",buttom_total_2018.values.tolist(),"\n2019 is",buttom_total_2019.values.tolist())
print("Top ACT average score 2017 is",top_total_2017.values.tolist(),
      "\n2018 is",top_total_2018.values.tolist(),"\n2019 is",top_total_2019.values.tolist())

top1_sat = sat_act_participation.sort_values('total_2017',ascending=False)[['state','total_2017']].head(3)
top2_sat = sat_act_participation.sort_values('total_2018',ascending=False)[['state','total_2018']].head(3)
top3_sat = sat_act_participation.sort_values('total_2019',ascending=False)[['state','total_2019']].head(3)
# Out:
# Lowest ACT average score 2017 is [['District of Columbia', 950]]
# 2018 is [['District of Columbia', 977]]
# 2019 is [['West Virginia', 943]]
# Top ACT average score 2017 is [['Minnesota', 1295]]
# 2018 is [['Minnesota', 1298]]
# 2019 is [['Minnesota', 1284]]

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
# ### Conclusion
# 1. If you need to improve the participation, do focus on state that have participation lower than 20% they growth with significantly like Colorado,  Illinois, West Virginia.
#     - Colorado,  Illinois, West Virginia state starting force juniors must take sat thats why it was increasing significantly(reference - https://blog.prepscholar.com/which-states-require-the-sat)
#     - From data comparison you can see that state which has 100% participant is state that ***require*** SAT for junior year
# 2. Negative co-relation between participant ACT and SAT is exactly true
#     - Most of student focus on testing either ACT or SAT. You can see from graph above if their is high participant in SAT, ACT will be lower
#     - Recommendation: focus on low state to improve participant of SAT percentage
# 3. Negative corelation between percent of participant and score is **"BIAS!!"**
#     - Firstly I have look through 3 years dataset of participant both ACT and SAT, it seems that the more participant rate, the lower the score.
#     - However, I look through Colorado,  Illinois, West Virginia which change from above the participant rate change differently but average score drop just a little.
#     - Therefore, I do outside research and found out that ***these averages score are biased by participation rates***. The lowest participating states tend to send primarily their best students and get highest scores.

# %% [markdown]
# ### Recommendation for increasing SAT participation rate
# 1. Fee of test: Make a contracted with the college board to administer the SAT to adminster the SAT to high school for free.
# 2. Provide free material: provide the material test of the previous year, so student can have more source to study and make interest in SAT test
# 3. Provide the knowledge: visiting highschool to provide the advantage and give knowledge to highschool student. It's much easier to convince them directly in face-to-face conversation. And we can also collecting data from student/teacher to improve the way we can communicate to them back.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
